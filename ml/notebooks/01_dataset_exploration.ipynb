# %%
import sys
from pathlib import Path

# Go up one level to the 'ml' folder and add it to the system path
ml_root = Path().resolve().parents[0]
sys.path.append(str(ml_root))

from src.data_loader import load_train_data

# Load the baseline dataset
train = load_train_data("FD001")

train.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       4 # Add the project root to the system path so we can import from src
#       5 project_root = Path().resolve().parents[1]
#       6 sys.path.append(str(project_root))
#       7
# ----> 8 from src.data_loader import load_train_data
#       9
#      10 # Load the baseline dataset
#      11 train = load_train_data("FD001")
#
# ModuleNotFoundError: No module named 'src'

# %%
train.shape

# %%
train.info()

# %%
train.describe()

# %%
train["engine_id"].nunique()

# %%
train.groupby("engine_id")["cycle"].max().describe()
